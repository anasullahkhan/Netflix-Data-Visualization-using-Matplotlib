# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x, y)
plt.show()

# %%
x = ['Mon', 'Tues', 'Wed', 'Thusr', 'Fri' ] #x-axis
y = [10,15,7,20,12] #y-axis

plt.plot(x,y)
plt.title('Bakery Sales This Week!')
plt.xlabel('day of the week')
plt.ylabel('sales per day')
plt.show()
